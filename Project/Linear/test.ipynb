# %%
import matplotlib.pyplot as plt

categories = ['a', 'b', 'c', 'd']
values = [20, 30, 40, 28]

plt.bar(categories, values)

plt.title('Biểu đồ cột')
plt.xlabel('Danh mục')
plt.ylabel('Giá trị')

for i, v in enumerate(values):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

plt.barh(categories, values)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4])
ypoints = np.array([3, 8])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4])
ypoints = np.array([3, 8])

plt.plot(xpoints, ypoints, marker='o', color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = [2, 4]
ypoints = [3, 8]

plt.plot(xpoints, ypoints, 'o:r', color='red')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17016\3929929627.py:7: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "o:r" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(xpoints, ypoints, 'o:r', color='red')

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4])
ypoints = np.array([3, 8])

plt.plot(xpoints, ypoints, marker='o', color='red')
plt.title('Graph line',color='b',loc='left')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4])
ypoints = np.array([3, 8])

plt.plot(xpoints, ypoints, marker='o', color='red')
plt.title('Graph line',color='b')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4])
ypoints = np.array([3, 8])

plt.plot(xpoints, ypoints, marker='o', color='red')
plt.title('Graph line',color='b',loc='left')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4])
ypoints = np.array([3, 8])

plt.scatter(xpoints, ypoints)

xpoints = np.array([5, 7])
ypoints = np.array([0, 9])

plt.scatter(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show() 

myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()
